# %% [markdown]
# # Elementos Básicos de Teoría de Probabilidades
#
# - Teoría de Probabilidades
# - Experimento, espacio muestral, evento
# - Definición Formal de Probabilidades
# - Probabilidades Condicionales, Independencia e Independecia Condicional
# - Ley de las Probabilidades Totales
# - Regla de Bayes
#
# **Teoría de Probabilidades**
# <span style="color:#0066CC">(Ideally, talk about history of probability)</span>
#
# - Modelamiento de fenómenos aleatorios (por ejemplo, lanzamiento de un dado, el tiempo)
# <img src="daos.jpg" width="200">
#
# - Fundamento de la estadística: que es la recolección, organización, análisis, interpretación y presentación de datos.
#
# **Experimento, Espacio Muestral, Evento**
#
# - Experimento: fenónemo aleatorio <span style="color:red">(not estoy segura)</span>
# - Espacio Muestral <span style="color:#0066CC">(sample space $\Omega$)</span>: conjunto de todos los posibles valores que puede tomar un experimento.
# - Evento <span style="color:#0066CC">($A$)</span>: cualquier subconjunto del espacio muestral. <span style="color:#0066CC">Un evento puede tener uno o multiple elementos.</span>
#        Ejemplos: “>8 caras en 10 lanzamientos de una moneda”, “mañana estará soleado en Valdivia”.
# - <span style="color:#0066CC">Elemento or resultado de la muestra ($\omega$): cada punto o valor en el espacio muestral.</span>
#
# <span style="color:#0066CC">Ejemplo: If we toss a coin twice then $\Omega$ = {HH,HT,TH,TT}.The event that the first toss is heads is A = {HH,HT}. The outcome that both tosses are heads is $\omega$ = {HH}.</span>

# %% [markdown]
# ## Probabilidades
# - ¿Qué tan posible es que un evento ocurra?
# - <span style="color:#0066CC">Probability is a mathematical language for quantifying uncertainty.</span>
#
# - <span style="color:red">Pros and cons of each perspective?</span>
# Dos perspectivas:
# - $\textbf{Enfoque frecuentista:}$ frecuencias observadas *al repetir muchas veces un experimento*.
#         La probablidad de obtener cara en el lanzamiento de una moneda es 0.5
#
# - $\textbf{Enfoque Bayesiano:}$ incertidumbre subjetiva, grado de creencia (a priori) que es revisado por la observación (probabilidad a posteriori).
#         Yo pienso que hay 0.1 de probabilidad de que un estudiante conozca este concepto.
#
# ### Definición Formal de Probabilidad
# <span style="color:#0066CC">(Cambié la primera parte de la definición basado en libro de WMMY y Wasserman y Queen Mary+PennState)</span>
#
# <span style="color:#0066CC">El grado de posibilidad de la ocurrencia de un evento que resulta de un experimento estadístico se evalúa utilizando un conjunto de números reales denominados **probabilidades**, que van de 0 a 1 (inclusivo). </span>
#
# **Definición**
#
# <span style="color:#0066CC">Probability is a function $P$ which assigns to each event $A$ in the sample space $\Omega$ a real number $P(A)$ such that:</span>
#
# $\begin{array}{ll} 1. & \forall A \subset \Omega, P(A) \geq 0\\
# 2. &  P(\Omega) = 1\\
# 3. & Sean \,\, A_1,...,A_n \subset \Omega: A_i \cap A_j =\phi, \forall i,j=1...n => P(A_1\cup...\cup A_n) = P(A_1)+...+P(A_n)\\
# \end{array}$
#
# The above three properties correspond to the three Kolmogorov axioms.
#
# **Propiedades**
#
# <span style="color:#0066CC">The following properties are deduced from the above Kolmogorov axioms:</span>
#
# 1. $P(A) = 1 - P(A^C)$ (the complement rule)
#
# 2. $ P(\phi) = 0$  (the probability of the empty set)
#
# 3. Si  $A \subseteq B => P(A) \leq P(B)$ (monotonicity)
#
# 4. $ 0 \leq P(A) \leq 1 $ (the numeric bound)
#
# 5. $ \forall A,B \in \Omega, P(A \cup B) = P(A) + P(B) - P(A \cap B)$ (the sum rule / the addition law of probability)
#
# :::{note}
#
# - <span style="color:#0066CC">The exact definition of the Kolmogorov axioms and the proof of above properties could be found in: https://en.wikipedia.org/wiki/Probability_axioms.</span>
# - <span style="color:#0066CC">The probability in Kolmogorov's axiomatic system is *abstract*. It doesn't tell us how to obtain probabilities. We will see next some common ways to obtain probabilities.</span>
# :::
#
# <span style="color:red">(set symbol rather than proper set symbol here? same questions below.)</span>

# %% [markdown]
# **¿Cómo asignamos valores de probabilidad?**
#
# <span style="color:#0066CC">(Ideally, talk about pros and limitations of each one; not sure of their names though)</span>
#
# - $\textbf{Enfoque frecuentista clásico:}$ Sea $n(A)$ el número elementos en el evento $A$, y $n(\Omega)$ el número de elementos en el espacio muestral $\Omega$, entonce $P(A) = \frac{n(A)}{n(\Omega)}$.
#
# - $\textbf{Enfoque frecuentista relativo:}$ Sea $n$ el número de experimentos, y $n(A)$ el número de veces que el evento $A$ ocurre en la realización de esos experimentos, entonces $P(A) = \frac{n(A)}{n}$.
#
# - $\textbf{Enfoque Bayesiano:}$ Yo pienso que la probabilidad de que me gane un proyecto es $0.9$ (probabilidad a priori).
#
# ### Probabilidades condicionales
# Sean $A, B \subset \Omega$, si $P(B)>0$, se define:
#
# $\begin{array}{lll}
# P(A\mid B) & = &\frac{P(A \cap B)}{P(B)}
# \end{array}$
#
# Si además se cumple que $P(A)>0$, se tiene:
#
# $\begin{array}{lll}
# P(A\cap B)& = &P(A\mid B)P(B) = P(B\mid A)P(A)
# \end{array}$
#
# Esto se puede extender a mas eventos:
#
# $\begin{array}{lll}
# P(A\cap B \cap C)& = &P(A)P(B\mid A) P(C\mid A \cap B)
# \end{array}$
#
# siempre que $P(A), P(A\cap B)> 0$

# %% [markdown]
# ### Independencia
# ¿Cómo determinar que dos eventos son independientes?
#
# Sean $A, B \subset \Omega$ con $P(A),P(B) >0$, si cualquiera de las siguientes condiciones se cumple:
#
#
# 1. $P(A\cap B) = P(A)P(B)$
#
# 2. $P(A\mid B)  =  P(A)$
#
# 3. $P(B\mid A)  = P(B)$
#
#
# se dice que $A$ es independiente de $B$.

# %% [markdown]
# ### Independencia Condicional
# ¿Cómo determinar que dos eventos $A$ y $B$ son independientes dados un tercer evento $C$?
#
# Sean $A, B, C \subset \Omega$ con $P(A\cap C),P(B\cap C), P(C)>0$, si cualquiera de las siguientes condiciones se cumple:
#
#
#
# 1. $P(A\cap B \mid C)  =  P(A\mid C)P(B\mid C)$
#
# 2. $P(A\mid B \cap C) =  P(A \mid C)$
#
# 3. $P(B\mid A \cap C)  =  P(B \mid C)$
#
# se dice que $A$ es independiente de $B$ condicionalmente a $C$.
#
# Ejemplo: Altura, Vocabulario y Edad

# %% [markdown]
# ### Ley de las Probabilidades totales
# Consideremos ahora una partición del espacio muestral $\{B_i\}_{i=1,..n}$, es decir:
#
# $\begin{array}{lll}
# \bigcup_{i=1}^n \limits  B_i = \Omega, & & B_i\cap B_j = \phi \qquad \forall i,j=1,..n, i\neq j
# \end{array}$
#
# entonces:
#
# $\begin{array}{lll}
# P(A) & = & \sum_{i=1}^n \limits P(A\mid B_i) P(B_i)
# \end{array}$
#
# Ejemplo: Sea $A$ = \{Pedro acepta trabajo en Chile\}
# y $B_i$ = \{Oferta de trabajo para Pedro en region $i$ \}, $i=1,...,15$
#
# <img src="chile.png" width="600">

# %% [markdown]
# ### Regla de Bayes
# A partir de la defición de probabilidades condicionales se puede deducir la regla de Bayes:
#
# Sean $A, B \subset \Omega$ tales que $P(A),P(B)>0$, entonces
#
# $\begin{array}{lll}
# P(B\mid A)& = & \frac{P(A\mid B) P(B)}{P(A)}
# \end{array}$
#
# $P(B)$ se denomina probabilidad a priori, $P(B \mid A)$ probabilidad a posteriori
#
# ### Teorema de Bayes
# Consideremos una partición del espacio muestral $\{B_i\}_{i=1,..n}$, entonces:
#
# $\begin{array}{lll}
# P(B_i \mid A) & = & \frac{P(A\mid B_i) P(B_i)}{P(A)}
# & = & \frac{P(A\mid B_i) P(B_i)}{\sum_{i=1}^n \limits P(A\mid B_i) P(B_i)}
# \end{array}$
#
# <span style="color:red">(Difference between the above; put examples)</span>
#
#
# <span style="color:#0066CC">(Add source: AoS ...)</span>
